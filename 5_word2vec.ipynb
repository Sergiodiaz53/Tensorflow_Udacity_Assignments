# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
# Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, 
                                                   train_labels,embed, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.238625
# Nearest to for: uptown, henotheistic, disappointed, skaldic, entropy, pennant, joost, knotted,
# Nearest to of: tectonic, prentice, automatic, duo, searchlight, fortaleza, kev, elly,
# Nearest to system: convert, composer, deleterious, faxes, magnificat, mirabeau, primer, oromo,
# Nearest to used: sayers, dancer, ecclestone, beac, jannaeus, network, docks, hailed,
# Nearest to all: sac, holes, policy, rose, belles, physicist, bucks, ruskin,
# Nearest to between: repulsive, significant, kees, ejecta, muhammad, assign, affray, dealings,
# Nearest to and: discomfort, hurley, vegetative, atanasoff, conditioner, soteriology, publicised, integrating,
# Nearest to states: asserts, anacharsis, homophones, quechua, negatively, livers, ingrid, dijkstra,
# Nearest to no: otimes, polka, chronological, bluebeard, pumps, ebionites, bogart, azerbaijan,
# Nearest to american: bot, cyanide, spinning, mom, messaging, encampments, progressing, algonquin,
# Nearest to its: mutate, guelfs, sw, amicus, dicke, icon, chee, ethan,
# Nearest to years: sofie, fingernails, xml, vlaams, sorenson, apologist, kilometer, aulus,
# Nearest to have: evangelista, household, guis, maul, wavy, wink, worldwide, physique,
# Nearest to during: codepoint, spectacularly, words, padma, garibaldi, unique, licentious, polynesian,
# Nearest to six: wiktionary, mellitus, backus, tardis, doublet, thrived, defiance, maududi,
# Nearest to this: constellations, rebuffed, desserts, universala, semipalatinsk, hussite, scorn, tabulating,
# Average loss at step 2000: 4.369974
# Average loss at step 4000: 3.864308
# Average loss at step 6000: 3.785415
# Average loss at step 8000: 3.689796
# Average loss at step 10000: 3.615807
# Nearest to for: veil, uptown, skaldic, rowland, of, with, in, entropy,
# Nearest to of: in, for, and, brine, polymath, benedictines, tectonic, following,
# Nearest to system: primer, faxes, saw, composer, skies, magnificat, quadrants, putting,
# Nearest to used: underrated, known, called, detonation, regarded, kristallnacht, sayers, homographs,
# Nearest to all: some, ruskin, qdos, rose, heaven, holes, scorn, our,
# Nearest to between: significant, ejecta, repulsive, eea, new, in, antics, reactors,
# Nearest to and: or, grizzly, without, of, by, d, epileptic, ccf,
# Nearest to states: asserts, negatively, anacharsis, ingrid, comets, banishing, undamaged, homophones,
# Nearest to no: otimes, it, bushman, gomez, kal, ebionites, won, stm,
# Nearest to american: bot, villas, extracts, chaplain, canadian, cyanide, kendall, spinning,
# Nearest to its: their, the, his, her, any, backward, shortly, wages,
# Nearest to years: mjt, pesky, mutiny, troppo, unsupported, cluny, xml, apollo,
# Nearest to have: had, be, has, were, are, darrow, uncovering, wastes,
# Nearest to during: in, on, from, aeroflot, reinforce, unique, leg, sgml,
# Nearest to six: eight, five, four, seven, three, nine, zero, two,
# Nearest to this: it, the, which, abolishing, a, his, fanon, that,
# Average loss at step 12000: 3.607120
# Average loss at step 14000: 3.571798
# Average loss at step 16000: 3.410130
# Average loss at step 18000: 3.456859
# Average loss at step 20000: 3.539700
# Nearest to for: with, veil, of, by, while, uptown, tactic, clout,
# Nearest to of: for, upper, original, connectionless, searchlight, brine, consignee, deformation,
# Nearest to system: primer, faxes, ct, saw, skies, quadrants, modula, prosperous,
# Nearest to used: known, called, lys, regarded, konami, detonation, found, taught,
# Nearest to all: some, many, these, scorn, several, ruskin, geographically, besht,
# Nearest to between: in, ejecta, with, significant, eea, er, rerum, reactors,
# Nearest to and: or, witch, but, who, restricts, schuster, gated, bisexuality,
# Nearest to states: asserts, anacharsis, negatively, ingrid, undamaged, banishing, monika, legislated,
# Nearest to no: otimes, bushman, there, any, it, kal, a, capitulation,
# Nearest to american: english, british, chaplain, canadian, tha, french, trakai, guerillas,
# Nearest to its: their, his, the, her, any, wages, our, representable,
# Nearest to years: people, furry, mjt, pesky, days, berliner, homepage, mutiny,
# Nearest to have: had, has, were, be, are, enthusiastic, pmid, captivity,
# Nearest to during: on, in, from, aeroflot, reinforce, cabot, tapu, uneducated,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to this: it, which, the, that, a, abolishing, lichens, what,
# Average loss at step 22000: 3.506473
# Average loss at step 24000: 3.494372
# Average loss at step 26000: 3.484224
# Average loss at step 28000: 3.482459
# Average loss at step 30000: 3.506385
# Nearest to for: skaldic, after, boadicea, when, with, veil, of, on,
# Nearest to of: in, including, for, from, tap, galindo, and, opposite,
# Nearest to system: primer, systems, skies, quadrants, twayne, voltaic, faxes, less,
# Nearest to used: known, called, regarded, found, lys, taught, available, konami,
# Nearest to all: some, these, many, geographically, several, ruskin, turbine, klaus,
# Nearest to between: with, ejecta, in, eea, er, amur, canetti, layla,
# Nearest to and: or, ausw, but, who, including, retrieving, lachlan, in,
# Nearest to states: kingdom, asserts, negatively, anacharsis, ingrid, neurath, ceremonies, lubricants,
# Nearest to no: any, otimes, kal, bushman, there, toys, stm, emmer,
# Nearest to american: british, english, canadian, german, australian, french, trakai, italian,
# Nearest to its: their, his, the, her, our, jain, any, representable,
# Nearest to years: days, people, times, berliner, mjt, listing, furry, phosphate,
# Nearest to have: had, has, were, are, be, having, do, wastes,
# Nearest to during: after, in, on, tapu, from, collapsing, uneducated, aeroflot,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to this: which, it, what, lichens, there, that, not, abolishing,
# Average loss at step 32000: 3.504068
# Average loss at step 34000: 3.494273
# Average loss at step 36000: 3.457423
# Average loss at step 38000: 3.307479
# Average loss at step 40000: 3.424310
# Nearest to for: skaldic, in, wider, of, if, uptown, when, while,
# Nearest to of: in, for, njazidja, original, disrespectful, actual, vignette, zanetti,
# Nearest to system: systems, primer, faxes, skies, rgen, quadrants, kyrgyzstan, voltaic,
# Nearest to used: known, found, taught, regarded, available, written, called, seen,
# Nearest to all: many, klaus, geographically, several, these, some, jd, copy,
# Nearest to between: with, ejecta, eea, from, in, following, against, amur,
# Nearest to and: or, but, in, while, like, witch, including, sequencing,
# Nearest to states: kingdom, countries, asserts, cathodes, negatively, anacharsis, ingrid, commemorated,
# Nearest to no: any, otimes, bushman, kal, there, monatomic, shaft, toys,
# Nearest to american: english, australian, canadian, british, tha, rojas, german, chaplain,
# Nearest to its: their, his, the, her, any, wages, our, shortly,
# Nearest to years: days, times, weeks, months, mjt, listing, pesky, frontispiece,
# Nearest to have: had, has, were, are, be, lozada, having, var,
# Nearest to during: after, in, on, at, snowflake, since, from, against,
# Nearest to six: four, seven, eight, five, three, nine, two, one,
# Nearest to this: which, it, that, any, the, abolishing, what, another,
# Average loss at step 42000: 3.439272
# Average loss at step 44000: 3.453344
# Average loss at step 46000: 3.446978
# Average loss at step 48000: 3.354046
# Average loss at step 50000: 3.387909
# Nearest to for: while, after, skaldic, veil, on, against, clout, brixton,
# Nearest to of: in, including, and, connectionless, bei, depressing, acceptors, upper,
# Nearest to system: systems, primer, quadrants, skies, krill, underwear, voltaic, kyrgyzstan,
# Nearest to used: known, regarded, found, available, performed, written, seen, taught,
# Nearest to all: both, many, geographically, these, some, klaus, several, each,
# Nearest to between: with, ejecta, periodicals, within, among, jarvis, asw, eea,
# Nearest to and: or, but, including, while, however, of, incongruous, although,
# Nearest to states: kingdom, asserts, nations, negatively, countries, state, grimoires, ceremonies,
# Nearest to no: any, otimes, emmer, another, kal, preserved, tonight, dario,
# Nearest to american: australian, english, canadian, german, chaplain, italian, french, trakai,
# Nearest to its: their, his, the, her, our, wages, representable, whose,
# Nearest to years: days, times, people, months, weeks, mjt, copies, phosphate,
# Nearest to have: had, has, were, are, be, do, hateful, lozada,
# Nearest to during: after, in, snowflake, from, at, when, under, collapsing,
# Nearest to six: eight, seven, four, three, five, nine, zero, two,
# Nearest to this: which, it, another, the, lichens, he, categorize, tacitus,
# Average loss at step 52000: 3.437931
# Average loss at step 54000: 3.428128
# Average loss at step 56000: 3.435773
# Average loss at step 58000: 3.397906
# Average loss at step 60000: 3.390935
# Nearest to for: of, skaldic, orloff, limitless, veil, including, in, uptown,
# Nearest to of: for, in, including, isaak, theroux, monteverdi, adas, from,
# Nearest to system: systems, primer, brewed, code, skies, sluggish, quadrants, circuit,
# Nearest to used: known, found, regarded, written, available, performed, taught, called,
# Nearest to all: many, some, every, these, several, various, those, any,
# Nearest to between: with, ejecta, within, among, periodicals, in, rapture, layla,
# Nearest to and: or, but, including, celts, doves, fastened, in, from,
# Nearest to states: kingdom, nations, countries, asserts, forces, grimoires, state, negatively,
# Nearest to no: any, emmer, otimes, overtook, little, kal, tonight, bushman,
# Nearest to american: australian, german, british, canadian, english, african, italian, french,
# Nearest to its: their, his, the, her, our, wages, whose, shortly,
# Nearest to years: days, months, times, weeks, year, people, centuries, phosphate,
# Nearest to have: has, had, are, were, be, include, lozada, valdemar,
# Nearest to during: after, in, before, snowflake, when, following, while, since,
# Nearest to six: eight, four, five, nine, seven, three, zero, one,
# Nearest to this: it, which, that, there, the, some, itself, kennedys,
# Average loss at step 62000: 3.234559
# Average loss at step 64000: 3.261116
# Average loss at step 66000: 3.405126
# Average loss at step 68000: 3.392327
# Average loss at step 70000: 3.363597
# Nearest to for: idi, while, skaldic, of, to, against, including, orloff,
# Nearest to of: including, for, although, cramer, like, and, in, include,
# Nearest to system: systems, primer, sluggish, brewed, underwear, quadrants, krill, prefers,
# Nearest to used: known, found, available, regarded, seen, performed, written, designed,
# Nearest to all: some, many, every, any, several, most, those, various,
# Nearest to between: with, among, within, from, ejecta, in, reactors, through,
# Nearest to and: or, but, while, like, cocteau, tailback, resuming, of,
# Nearest to states: kingdom, nations, countries, state, asserts, negatively, dijkstra, grimoires,
# Nearest to no: any, little, otimes, emmer, dario, there, overtook, bushman,
# Nearest to american: british, australian, italian, canadian, german, english, western, african,
# Nearest to its: their, his, her, the, our, wages, shortly, representable,
# Nearest to years: days, months, weeks, decades, times, year, centuries, copies,
# Nearest to have: had, has, were, are, be, having, include, botanical,
# Nearest to during: after, before, in, until, snowflake, while, since, following,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to this: which, it, the, that, another, there, any, some,
# Average loss at step 72000: 3.373956
# Average loss at step 74000: 3.351185
# Average loss at step 76000: 3.314119
# Average loss at step 78000: 3.354196
# Average loss at step 80000: 3.378144
# Nearest to for: skaldic, uptown, after, idi, pangloss, when, while, including,
# Nearest to of: including, xico, adas, vignette, pashto, baserunners, gsm, in,
# Nearest to system: systems, primer, rhinoceros, code, sluggish, prefers, wishing, civilize,
# Nearest to used: known, found, available, seen, written, regarded, performed, referred,
# Nearest to all: every, many, various, both, any, several, these, geographically,
# Nearest to between: within, among, with, from, ejecta, reactors, nhl, through,
# Nearest to and: or, while, but, including, qutb, witch, incongruous, although,
# Nearest to states: kingdom, nations, countries, state, asserts, negatively, ceremonies, sidewinder,
# Nearest to no: little, any, otimes, bushman, emmer, there, suits, tonight,
# Nearest to american: british, australian, canadian, italian, german, french, irish, english,
# Nearest to its: their, his, her, our, the, wages, your, shortly,
# Nearest to years: days, months, weeks, times, decades, year, minutes, centuries,
# Nearest to have: had, has, are, be, were, having, include, ingmar,
# Nearest to during: after, in, before, when, until, despite, snowflake, on,
# Nearest to six: five, seven, four, eight, three, nine, two, one,
# Nearest to this: which, it, another, some, itself, the, there, reinvention,
# Average loss at step 82000: 3.405254
# Average loss at step 84000: 3.406644
# Average loss at step 86000: 3.389378
# Average loss at step 88000: 3.354754
# Average loss at step 90000: 3.364910
# Nearest to for: while, skaldic, without, after, of, if, when, against,
# Nearest to of: including, for, geysers, in, although, adas, peano, actual,
# Nearest to system: systems, primer, flag, obp, hannover, jessie, naphtali, civilize,
# Nearest to used: seen, known, found, regarded, referred, available, performed, designed,
# Nearest to all: many, several, every, various, some, both, any, those,
# Nearest to between: within, with, among, in, ejecta, from, periodicals, against,
# Nearest to and: or, but, while, witch, although, in, hideo, including,
# Nearest to states: kingdom, nations, asserts, state, countries, negatively, ceremonies, officials,
# Nearest to no: little, any, emmer, organists, otimes, suits, dario, bushman,
# Nearest to american: british, australian, canadian, italian, german, french, african, irish,
# Nearest to its: their, his, her, the, our, wages, whose, your,
# Nearest to years: days, months, weeks, decades, year, centuries, hours, times,
# Nearest to have: had, has, are, were, having, be, lozada, include,
# Nearest to during: after, in, before, until, while, when, at, despite,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to this: which, it, the, some, rowling, walruses, any, zine,
# Average loss at step 92000: 3.399899
# Average loss at step 94000: 3.253426
# Average loss at step 96000: 3.364091
# Average loss at step 98000: 3.239984
# Average loss at step 100000: 3.353246
# Nearest to for: skaldic, without, if, when, against, while, after, before,
# Nearest to of: including, and, in, vignette, gast, by, depressing, matthias,
# Nearest to system: systems, primer, sluggish, quadrants, obp, proof, model, skies,
# Nearest to used: found, seen, performed, available, written, designed, known, applied,
# Nearest to all: many, several, various, these, every, some, any, those,
# Nearest to between: with, among, within, periodicals, jarvis, exact, reactors, against,
# Nearest to and: or, but, while, although, however, cleverly, of, when,
# Nearest to states: kingdom, nations, asserts, countries, state, officials, ceremonies, negatively,
# Nearest to no: little, any, emmer, otimes, organists, tonight, there, dario,
# Nearest to american: canadian, british, australian, italian, irish, trakai, french, german,
# Nearest to its: their, his, our, the, her, wages, indiscriminately, whose,
# Nearest to years: days, months, decades, weeks, year, times, hours, minutes,
# Nearest to have: had, has, are, were, having, be, include, contain,
# Nearest to during: after, in, before, following, until, at, when, throughout,
# Nearest to six: seven, four, eight, nine, five, three, zero, two,
# Nearest to this: which, it, he, there, the, some, excerpted, itself,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-11-fc41ad24bff7>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.869482
# Nearest to for: undergo, vulva, strasbourg, dismounted, licinius, chimpanzees, decades, beginning,
# Nearest to of: nomadic, amazed, cachet, deir, pepin, neuromuscular, microkernels, hamdi,
# Nearest to system: mercantilism, auditum, marianne, forgiven, homilies, ncsa, archivers, courtiers,
# Nearest to used: restrictive, pressured, agostino, writ, coaxial, milius, gunpowder, grasses,
# Nearest to all: predicted, marcomanni, pets, liu, gifford, intuitive, smashing, boulder,
# Nearest to between: forerunners, transfer, pedestrian, exemptions, tautologies, oro, sulfuric, irregularity,
# Nearest to and: arbitrators, cheesemaking, universitet, scrat, florentines, drone, birley, railhead,
# Nearest to states: poisonous, fellowships, eridanus, creationist, henriette, neva, ask, orthography,
# Nearest to no: mortimer, equations, naka, dopant, legacy, etymologically, payments, transplant,
# Nearest to american: langue, switzer, thrones, afrikaners, channing, puritanism, overwhelms, saimei,
# Nearest to its: escoffier, monarch, anne, tt, cantus, sugarcubes, callisto, hippos,
# Nearest to years: peanuts, christina, wallabies, valproate, futurology, tet, improvised, maritimes,
# Nearest to have: altman, vied, exaggerate, ploughing, malarial, mps, dilute, suppliers,
# Nearest to during: suggesting, injera, blocs, alaskan, exogenous, veins, arminians, orphanage,
# Nearest to six: lift, radioactive, scythians, westernmost, bedroom, abyssinian, exercise, radios,
# Nearest to this: enhance, wickham, lauter, lawful, marcia, upstate, nouvelle, curly,
# Average loss at step 2000: 4.376405
# Average loss at step 4000: 3.882381
# Average loss at step 6000: 3.810982
# Average loss at step 8000: 3.760108
# Average loss at step 10000: 3.619898
# Nearest to for: or, and, of, in, scaling, michel, on, is,
# Nearest to of: in, for, and, vfr, with, outbreaks, pepin, quake,
# Nearest to system: believer, cause, eschews, indicative, criticised, urbana, courtiers, transhumanism,
# Nearest to used: restrictive, nato, jezreel, milius, mistletoe, ephraim, agostino, patriarch,
# Nearest to all: leningrad, many, pcs, parliament, pets, lagos, booth, fergus,
# Nearest to between: with, pedestrian, aggregates, src, in, transactions, transfer, forerunners,
# Nearest to and: or, in, with, for, from, of, to, on,
# Nearest to states: nations, poisonous, fellowships, henriette, creationist, members, insure, ask,
# Nearest to no: equations, traditionally, mortimer, dopant, a, naka, omim, doors,
# Nearest to american: asshole, pda, puritanism, theological, arthritis, preferring, mechanised, saucer,
# Nearest to its: their, the, his, teschen, callisto, anne, vertically, miyazaki,
# Nearest to years: valproate, christina, smoked, tet, cities, hackney, csu, chatham,
# Nearest to have: has, be, had, are, were, frasier, exaggerate, colourless,
# Nearest to during: into, alaskan, usual, suggesting, blocs, marquee, yog, xc,
# Nearest to six: eight, five, four, seven, nine, three, zero, one,
# Nearest to this: it, which, the, that, protocol, bibliographic, rammstein, pots,
# Average loss at step 12000: 3.583641
# Average loss at step 14000: 3.617206
# Average loss at step 16000: 3.586899
# Average loss at step 18000: 3.572572
# Average loss at step 20000: 3.548594
# Nearest to for: at, in, fashioned, causeway, to, michel, enthalpy, consciously,
# Nearest to of: in, and, amazed, bangui, amputation, supplant, apologies, s,
# Nearest to system: believer, cause, transhumanism, absolutism, paullus, hexagram, forgiven, indicative,
# Nearest to used: known, jezreel, seen, restrictive, mistletoe, nato, found, defined,
# Nearest to all: many, some, pcs, any, lagos, several, watterson, pets,
# Nearest to between: with, pedestrian, in, aggregates, src, throughout, electronically, civil,
# Nearest to and: or, of, s, colloquially, in, monolithic, chechens, typical,
# Nearest to states: nations, poisonous, creationist, members, prominently, cryptic, recaptured, fellowships,
# Nearest to no: equations, haas, traditionally, prototyping, doors, dopant, widely, transplant,
# Nearest to american: theological, asshole, fletcher, pda, british, english, extensionality, page,
# Nearest to its: their, his, the, any, a, nucleotides, phrased, miyazaki,
# Nearest to years: valproate, smoked, weeks, eastbound, umlauts, christina, exam, microprogram,
# Nearest to have: had, has, are, be, were, do, argue, bluntly,
# Nearest to during: into, in, usual, sumerian, after, suggesting, over, alaskan,
# Nearest to six: four, five, seven, eight, nine, three, zero, two,
# Nearest to this: it, which, that, protocol, the, unison, a, cl,
# Average loss at step 22000: 3.530762
# Average loss at step 24000: 3.437861
# Average loss at step 26000: 3.421386
# Average loss at step 28000: 3.477072
# Average loss at step 30000: 3.411248
# Nearest to for: in, at, to, of, ideological, if, humanists, among,
# Nearest to of: in, and, apologies, supplant, majin, for, collectivist, including,
# Nearest to system: believer, systems, hexagram, eschews, trademarked, paullus, cause, ransom,
# Nearest to used: known, seen, jezreel, restrictive, found, considered, possible, expected,
# Nearest to all: many, some, these, any, end, every, falwell, rabbani,
# Nearest to between: with, pedestrian, electronically, src, aggregates, in, civil, throughout,
# Nearest to and: or, in, of, but, who, almaty, polish, insured,
# Nearest to states: nations, poisonous, creationist, kingdom, cryptic, recaptured, nouveau, prohibitions,
# Nearest to no: or, traditionally, equations, haas, omim, prototyping, transplant, calories,
# Nearest to american: british, french, marriott, langue, channing, hydrofoil, lisa, usc,
# Nearest to its: their, his, the, any, nucleotides, miyazaki, yelling, upside,
# Nearest to years: valproate, months, times, weeks, year, days, eastbound, smoked,
# Nearest to have: had, has, be, were, are, cries, insensitive, do,
# Nearest to during: in, sumerian, when, suggesting, after, at, under, iib,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to this: it, which, the, there, that, some, rammstein, argumentative,
# Average loss at step 32000: 3.418753
# Average loss at step 34000: 3.448666
# Average loss at step 36000: 3.364698
# Average loss at step 38000: 3.491867
# Average loss at step 40000: 3.442496
# Nearest to for: algorithmic, if, requiem, after, of, by, when, disinfectant,
# Nearest to of: including, in, for, cautions, apologies, although, supernaturally, praetorius,
# Nearest to system: systems, believer, engineering, eschews, cta, absolutism, negri, marlborough,
# Nearest to used: known, seen, jezreel, found, called, described, written, considered,
# Nearest to all: many, some, these, every, any, dem, nrsv, each,
# Nearest to between: with, pedestrian, electronically, throughout, civil, src, therapeutic, among,
# Nearest to and: or, but, which, carpenters, pick, harmless, of, with,
# Nearest to states: nations, kingdom, creationist, poisonous, cryptic, luggage, members, recaptured,
# Nearest to no: a, any, memorized, yarmouth, it, efficient, impeller, inexpensively,
# Nearest to american: british, aurora, asshole, theological, hydrofoil, african, andover, spanish,
# Nearest to its: their, his, the, nucleotides, s, any, her, stubby,
# Nearest to years: times, months, days, weeks, year, decades, umlauts, eastbound,
# Nearest to have: had, has, were, be, are, yield, cries, refer,
# Nearest to during: in, after, under, when, throughout, before, however, sumerian,
# Nearest to six: eight, seven, five, four, nine, zero, two, three,
# Nearest to this: which, it, the, some, that, helene, utopia, rau,
# Average loss at step 42000: 3.430514
# Average loss at step 44000: 3.271677
# Average loss at step 46000: 3.410591
# Average loss at step 48000: 3.427173
# Average loss at step 50000: 3.438952
# Nearest to for: when, after, without, if, of, requiem, before, algorithmic,
# Nearest to of: in, for, original, sucrose, after, during, mannerisms, including,
# Nearest to system: systems, believer, inordinate, eschews, belief, bothwell, musicians, absolutism,
# Nearest to used: known, described, referred, seen, defined, considered, presents, found,
# Nearest to all: many, some, these, every, each, any, nrsv, both,
# Nearest to between: with, pedestrian, in, throughout, electronically, from, wimbledon, src,
# Nearest to and: or, but, s, detonator, when, quell, however, with,
# Nearest to states: nations, kingdom, poisonous, cryptic, creationist, sampa, starcraft, bromide,
# Nearest to no: any, a, traditionally, calories, memorized, efficient, coll, excited,
# Nearest to american: british, theological, african, music, french, america, andover, canadian,
# Nearest to its: their, his, the, her, any, nucleotides, our, monarchical,
# Nearest to years: months, days, weeks, times, decades, year, valproate, eastbound,
# Nearest to have: had, has, be, were, are, refer, contain, yield,
# Nearest to during: when, after, before, in, throughout, under, however, since,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to this: it, which, some, the, argumentative, inquired, tb, dubliners,
# Average loss at step 52000: 3.460698
# Average loss at step 54000: 3.429015
# Average loss at step 56000: 3.408676
# Average loss at step 58000: 3.285603
# Average loss at step 60000: 3.381326
# Nearest to for: when, despite, causeway, ideological, while, after, without, from,
# Nearest to of: including, amazed, denslow, vfr, in, apologies, praetorius, majin,
# Nearest to system: systems, hexagram, believer, eschews, absolutism, engineering, trademarked, inordinate,
# Nearest to used: known, referred, seen, defined, described, considered, called, found,
# Nearest to all: some, many, several, both, these, any, every, each,
# Nearest to between: with, pedestrian, throughout, among, from, into, within, moray,
# Nearest to and: or, but, including, vocational, delicately, pick, s, from,
# Nearest to states: nations, kingdom, sampa, cryptic, creationist, balzac, rivers, countries,
# Nearest to no: any, little, it, calories, a, necessary, induced, ewing,
# Nearest to american: british, african, french, canadian, english, theological, italian, basses,
# Nearest to its: their, his, the, her, our, monarchical, some, milah,
# Nearest to years: days, months, decades, times, weeks, centuries, year, valproate,
# Nearest to have: had, has, were, be, are, refer, yield, formulate,
# Nearest to during: after, in, before, throughout, since, when, under, at,
# Nearest to six: five, eight, four, seven, nine, three, two, zero,
# Nearest to this: which, it, that, the, lakshadweep, any, phased, some,
# Average loss at step 62000: 3.439965
# Average loss at step 64000: 3.361399
# Average loss at step 66000: 3.343018
# Average loss at step 68000: 3.388103
# Average loss at step 70000: 3.368447
# Nearest to for: after, when, while, although, by, causeway, among, with,
# Nearest to of: including, carlist, actual, unsuspecting, apologies, gaius, in, for,
# Nearest to system: systems, believer, hexagram, latterly, absolutism, trademarked, eschews, inordinate,
# Nearest to used: known, described, seen, referred, called, defined, presents, responsible,
# Nearest to all: some, both, many, several, most, every, various, these,
# Nearest to between: with, pedestrian, throughout, from, into, in, within, among,
# Nearest to and: or, but, while, including, contemplates, than, see, however,
# Nearest to states: nations, kingdom, ontology, cryptic, contralto, creationist, protector, poisonous,
# Nearest to no: any, little, another, a, rsc, necessary, traditionally, escudo,
# Nearest to american: british, french, african, theological, basses, italian, canadian, russian,
# Nearest to its: their, his, the, her, our, janus, whose, utopia,
# Nearest to years: days, months, decades, times, centuries, weeks, year, hours,
# Nearest to have: had, has, were, be, are, yield, refer, having,
# Nearest to during: in, after, before, since, throughout, under, however, at,
# Nearest to six: seven, eight, nine, five, four, three, two, zero,
# Nearest to this: which, it, another, the, helene, each, any, some,
# Average loss at step 72000: 3.404038
# Average loss at step 74000: 3.383376
# Average loss at step 76000: 3.353479
# Average loss at step 78000: 3.238079
# Average loss at step 80000: 3.376831
# Nearest to for: ideological, if, bodmin, when, without, while, of, weathered,
# Nearest to of: in, and, including, concerning, mccarthyism, lorne, fundamental, for,
# Nearest to system: systems, believer, eschews, marlborough, hornet, absolutism, trademarked, hastings,
# Nearest to used: known, called, referred, required, described, seen, responsible, presents,
# Nearest to all: both, every, most, many, some, any, none, each,
# Nearest to between: with, pedestrian, among, within, into, from, throughout, against,
# Nearest to and: or, but, including, while, of, vocational, than, however,
# Nearest to states: nations, kingdom, countries, jurisdictions, officials, cryptic, us, denominations,
# Nearest to no: any, little, coll, positing, there, escudo, elliott, phenol,
# Nearest to american: british, french, african, theological, basses, german, irish, intolerance,
# Nearest to its: their, his, the, whose, our, her, hilberg, some,
# Nearest to years: days, months, decades, centuries, year, weeks, times, minutes,
# Nearest to have: had, has, were, are, yield, be, include, having,
# Nearest to during: after, before, in, throughout, since, under, through, following,
# Nearest to six: seven, five, four, nine, eight, three, zero, two,
# Nearest to this: which, the, it, another, any, some, each, unison,
# Average loss at step 82000: 3.295798
# Average loss at step 84000: 3.339881
# Average loss at step 86000: 3.350394
# Average loss at step 88000: 3.316927
# Average loss at step 90000: 3.239917
# Nearest to for: after, kokhba, despite, causeway, azam, groundbreaking, recompilation, as,
# Nearest to of: in, wesleyan, including, and, despite, essences, sidra, juvenile,
# Nearest to system: systems, believer, absolutism, ncsa, marlborough, suborbital, hexagram, commission,
# Nearest to used: referred, described, known, required, seen, found, called, defined,
# Nearest to all: many, every, both, various, these, several, some, most,
# Nearest to between: with, pedestrian, against, among, from, throughout, within, loyalist,
# Nearest to and: or, including, but, american, cathy, who, of, birley,
# Nearest to states: nations, kingdom, state, us, lone, countries, cryptic, melton,
# Nearest to no: little, any, coll, elliott, mca, positing, escudo, incarcerated,
# Nearest to american: british, canadian, french, german, english, singularities, and, neat,
# Nearest to its: their, his, her, whose, the, our, milah, some,
# Nearest to years: days, months, decades, centuries, weeks, year, hours, minutes,
# Nearest to have: had, has, yield, are, be, were, refer, having,
# Nearest to during: after, in, before, when, throughout, at, since, following,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to this: it, which, the, tb, some, maaouya, each, another,
# Average loss at step 92000: 2.741526
# Average loss at step 94000: 3.106673
# Average loss at step 96000: 3.066464
# Average loss at step 98000: 3.224493
# Average loss at step 100000: 3.279497
# Nearest to for: without, after, despite, by, of, stock, ideological, bodmin,
# Nearest to of: actual, concerning, for, wesleyan, including, despite, and, convolutions,
# Nearest to system: systems, hexagram, pathways, marlborough, believer, engineering, absolutism, suborbital,
# Nearest to used: known, described, referred, seen, required, designed, published, called,
# Nearest to all: these, every, each, many, some, both, several, those,
# Nearest to between: with, among, in, against, pedestrian, throughout, within, from,
# Nearest to and: or, but, including, while, however, though, which, who,
# Nearest to states: nations, kingdom, us, state, cryptic, officials, jurisdictions, countries,
# Nearest to no: little, any, another, intercity, elliott, coll, escudo, sophocles,
# Nearest to american: british, english, canadian, german, african, french, italian, australian,
# Nearest to its: their, his, her, the, our, whose, stubby, restorative,
# Nearest to years: days, months, decades, centuries, minutes, weeks, year, hours,
# Nearest to have: had, has, are, be, were, having, yield, include,
# Nearest to during: after, in, at, before, throughout, under, when, following,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to this: which, the, it, another, some, that, his, maaouya,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
